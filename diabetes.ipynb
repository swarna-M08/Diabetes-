# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Load Diabetes dataset

# %%
from sklearn.datasets import load_diabetes

# %%
data = load_diabetes()
data
# Out:
# {'data': array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#           0.01990842, -0.01764613],
#         [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#          -0.06832974, -0.09220405],
#         [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#           0.00286377, -0.02593034],
#         ...,
#         [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#          -0.04687948,  0.01549073],
#         [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#           0.04452837, -0.02593034],
#         [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#          -0.00421986,  0.00306441]]),
#  'target': array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#          69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#          68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#          87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
# ...

# %%
type(data)
# Out:
# sklearn.utils.Bunch

# %%
data.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'DESCR', 'feature_names', 'data_filename', 'target_filename', 'data_module'])

# %%
print(data.DESCR)
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
#   :Number of Instances: 442
#
#   :Number of Attributes: First 10 columns are numeric predictive values
#
#   :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
#   :Attribute Information:
#       - age     age in years
#       - sex
#       - bmi     body mass index
#       - bp      average blood pressure
#       - s1      tc, total serum cholesterol
#       - s2      ldl, low-density lipoproteins
#       - s3      hdl, high-density lipoproteins
#       - s4      tch, total cholesterol / HDL
#       - s5      ltg, possibly log of serum triglycerides level
# ...

# %%
data.target
# Out:
# array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#        259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#        128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#        150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#        200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#         42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#         83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#        104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#        173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#        107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
# ...

# %%
data.feature_names
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %% [markdown]
# Preparing the dataset

# %%
dataset = pd.DataFrame(data.data, columns = data.feature_names)

# %%
dataset.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019908 -0.017646
# 1 -0.039493 -0.068330 -0.092204
# 2 -0.002592  0.002864 -0.025930
# 3  0.034309  0.022692 -0.009362
# 4 -0.002592 -0.031991 -0.046641

# %%
dataset['Outcome'] = data.target

# %%
dataset.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  Outcome
# 0 -0.002592  0.019908 -0.017646    151.0
# 1 -0.039493 -0.068330 -0.092204     75.0
# 2 -0.002592  0.002864 -0.025930    141.0
# 3  0.034309  0.022692 -0.009362    206.0
# 4 -0.002592 -0.031991 -0.046641    135.0

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   age      442 non-null    float64
#  1   sex      442 non-null    float64
#  2   bmi      442 non-null    float64
#  3   bp       442 non-null    float64
#  4   s1       442 non-null    float64
#  5   s2       442 non-null    float64
#  6   s3       442 non-null    float64
#  7   s4       442 non-null    float64
#  8   s5       442 non-null    float64
#  9   s6       442 non-null    float64
#  10  Outcome  442 non-null    float64
# dtypes: float64(11)
# memory usage: 38.1 KB

# %% [markdown]
# Summarizing the stats of the data

# %%
dataset.describe()
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -3.639623e-16  1.309912e-16 -8.013951e-16  1.289818e-16 -9.042540e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123996e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665645e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670611e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564384e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320442e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   1.301121e-16 -4.563971e-16  3.863174e-16 -3.848103e-16 -3.398488e-16
# ...

# %% [markdown]
# Checking the missing values

# %%
dataset.isnull().sum()
# Out:
# age        0
# sex        0
# bmi        0
# bp         0
# s1         0
# s2         0
# s3         0
# s4         0
# s5         0
# s6         0
# Outcome    0
# dtype: int64

# %% [markdown]
# Exploratory Data Analysis(EDA)

# %%
dataset.corr()
# Out:
#               age       sex       bmi        bp        s1        s2        s3  \
# age      1.000000  0.173737  0.185085  0.335427  0.260061  0.219243 -0.075181
# sex      0.173737  1.000000  0.088161  0.241013  0.035277  0.142637 -0.379090
# bmi      0.185085  0.088161  1.000000  0.395415  0.249777  0.261170 -0.366811
# bp       0.335427  0.241013  0.395415  1.000000  0.242470  0.185558 -0.178761
# s1       0.260061  0.035277  0.249777  0.242470  1.000000  0.896663  0.051519
# s2       0.219243  0.142637  0.261170  0.185558  0.896663  1.000000 -0.196455
# s3      -0.075181 -0.379090 -0.366811 -0.178761  0.051519 -0.196455  1.000000
# s4       0.203841  0.332115  0.413807  0.257653  0.542207  0.659817 -0.738493
# s5       0.270777  0.149918  0.446159  0.393478  0.515501  0.318353 -0.398577
# s6       0.301731  0.208133  0.388680  0.390429  0.325717  0.290600 -0.273697
# Outcome  0.187889  0.043062  0.586450  0.441484  0.212022  0.174054 -0.394789
#
# ...

# %%
import seaborn as sns
sns.pairplot(dataset)

# %%
plt.scatter(dataset['bmi'], dataset['Outcome'])
plt.xlabel('BMI')
plt.ylabel('Outcome')
plt.title('BMI vs Outcome')
plt.show()

# %%
plt.scatter(dataset['s3'], dataset['Outcome'])
plt.xlabel('High-density lipoproteins')
plt.ylabel('Outcome')
plt.title('High-density lipoproteins vs Outcome')
plt.show()

# %%
sns.regplot(x = 'bmi', y = 'Outcome', data = dataset)
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='Outcome'>

# %%
sns.regplot(x = 's3', y = 'Outcome', data = dataset)
# Out:
# <AxesSubplot:xlabel='s3', ylabel='Outcome'>

# %%
sns.regplot(x = 'sex', y = 'Outcome', data = dataset)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='Outcome'>

# %% [markdown]
# Dependent and Independent features

# %%
X = dataset.iloc[:,:-1]
y = dataset.iloc[:,-1]

# %%
X.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019908 -0.017646
# 1 -0.039493 -0.068330 -0.092204
# 2 -0.002592  0.002864 -0.025930
# 3  0.034309  0.022692 -0.009362
# 4 -0.002592 -0.031991 -0.046641

# %%
y.head()
# Out:
# 0    151.0
# 1     75.0
# 2    141.0
# 3    206.0
# 4    135.0
# Name: Outcome, dtype: float64

# %%
#train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, random_state=8)

# %%
X_train
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 158 -0.012780 -0.044642 -0.065486 -0.069938  0.001183  0.016849 -0.002903
# 424  0.001751  0.050680  0.011039 -0.019442 -0.016704 -0.003819 -0.047082
# 382  0.048974 -0.044642  0.060618 -0.022885 -0.023584 -0.072712 -0.043401
# 294  0.023546  0.050680 -0.030996 -0.005671 -0.016704  0.017788 -0.032356
# 366 -0.045472  0.050680  0.137143 -0.015999  0.041086  0.031880 -0.043401
# ..        ...       ...       ...       ...       ...       ...       ...
# 339  0.027178 -0.044642 -0.007284 -0.050428  0.075484  0.056619  0.033914
# 136 -0.092695 -0.044642 -0.081653 -0.057314 -0.060735 -0.068014  0.048640
# 133 -0.041840  0.050680 -0.053630 -0.040099 -0.084126 -0.071772 -0.002903
# 361  0.041708 -0.044642 -0.007284  0.028758 -0.042848 -0.048286  0.052322
# 340 -0.016412 -0.044642 -0.013751  0.132044 -0.009825 -0.003819  0.019187
#
#            s4        s5        s6
# 158 -0.007020 -0.030751 -0.050783
# ...

# %%
X_test
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 367 -0.009147  0.050680  0.170555  0.014987  0.030078  0.033759 -0.021311
# 219 -0.089063 -0.044642 -0.041774 -0.019442 -0.066239 -0.074277  0.008142
# 72   0.063504  0.050680 -0.004050 -0.012556  0.103003  0.048790  0.056003
# 55  -0.041840 -0.044642 -0.049318 -0.036656 -0.007073 -0.022608  0.085456
# 371  0.052606  0.050680 -0.009439  0.049415  0.050717 -0.019163 -0.013948
# ..        ...       ...       ...       ...       ...       ...       ...
# 65  -0.045472  0.050680 -0.024529  0.059744  0.005311  0.014970 -0.054446
# 114  0.023546 -0.044642  0.110198  0.063187  0.013567 -0.032942 -0.024993
# 182  0.045341  0.050680  0.005650  0.056301  0.064477  0.089186 -0.039719
# 417 -0.052738 -0.044642  0.071397 -0.074528 -0.015328 -0.001314  0.004460
# 224 -0.027310 -0.044642 -0.066563 -0.112400 -0.049727 -0.041397  0.000779
#
#            s4        s5        s6
# 367  0.034309  0.033657  0.032059
# ...

# %%
y_train
# Out:
# 158     96.0
# 424    111.0
# 382    132.0
# 294     55.0
# 366    233.0
#        ...
# 339     95.0
# 136     85.0
# 133     83.0
# 361    182.0
# 340    216.0
# Name: Outcome, Length: 309, dtype: float64

# %%
y_test
# Out:
# 367    242.0
# 219    185.0
# 72     202.0
# 55     128.0
# 371    197.0
#        ...
# 65     163.0
# 114    258.0
# 182    138.0
# 417     55.0
# 224     77.0
# Name: Outcome, Length: 133, dtype: float64

# %% [markdown]
# Standardizing the dataset

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
import pickle
pickle.dump(scaler,open('scaling.pkl','wb'))

# %%
X_train
# Out:
# array([[-0.31354794, -0.95257934, -1.38160583, ..., -0.1346093 ,
#         -0.66275698, -1.10412761],
#        [ 0.0041121 ,  1.04978132,  0.25541352, ...,  0.72095701,
#          0.49384814,  0.4762012 ],
#        [ 1.03650724, -0.95257934,  1.31601761, ..., -0.04294148,
#          2.18400039,  0.73958934],
#        ...,
#        [-0.94886802,  1.04978132, -1.12798311, ..., -0.80683996,
#         -1.53600189, -0.66514739],
#        [ 0.87767722, -0.95257934, -0.13654886, ..., -1.57073845,
#         -1.53600189,  0.4762012 ],
#        [-0.39296295, -0.95257934, -0.27488852, ..., -0.80683996,
#         -0.76966207, -0.66514739]])

# %%
X_test
# Out:
# array([[-0.23413293,  1.04978132,  3.66779189, ...,  0.72095701,
#          0.69654034,  0.6517933 ],
#        [-1.98126316, -0.95257934, -0.8743604 , ..., -0.80683996,
#          0.01037031, -0.66514739],
#        [ 1.35416729,  1.04978132, -0.06737903, ..., -0.04294148,
#          1.7694594 , -0.40175925],
#        ...,
#        [ 0.95709223,  1.04978132,  0.14013047, ...,  1.48485549,
#          0.31476111, -0.22616716],
#        [-1.18711306, -0.95257934,  1.54658371, ..., -0.43252971,
#         -1.00313567,  0.03722098],
#        [-0.63120798, -0.95257934, -1.40466244, ..., -0.80683996,
#         -0.76966207, -0.22616716]])

# %% [markdown]
# Model Training

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression()

# %%
regression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#print the coefficients and intercepts
print(regression.coef_)
print(regression.intercept_)
# Out:
# [  0.5892473  -13.34147264  24.58820919  19.23214585 -54.8190016
#   34.33896204  11.00880208  10.06795404  38.66548743   5.42443032]
# 152.3915857605178

# %%
regression.get_params()
# Out:
# {'copy_X': True,
#  'fit_intercept': True,
#  'n_jobs': None,
#  'normalize': 'deprecated',
#  'positive': False}

# %%
#prediction with the test data
reg_pred = regression.predict(X_test)
reg_pred
# Out:
# array([257.23517855, 147.44586692, 130.12580766,  74.13446503,
#        183.22186362, 147.22209301, 187.73107346, 200.29393518,
#        133.49024693, 148.61038737, 208.89331944, 146.01872162,
#         61.79771159,  58.45890486, 142.04176005, 207.76087478,
#         70.01577252,  39.27820321, 205.63484311, 165.33673884,
#        195.03688396, 115.37905113, 185.82912582, 140.30898747,
#        149.40974983, 207.43918688, 164.34395682, 188.04177179,
#        106.46182798,  35.7022114 , 223.60248871, 183.36887262,
#        148.47816504, 166.62842734,  53.11140671, 268.88345328,
#         99.97149059, 120.96608137, 164.01815292, 117.16026036,
#         95.86144122,  47.93097946, 185.97818463,  55.53060718,
#         77.73413446,  97.9760115 ,  90.86225035, 131.2928181 ,
#        266.68227378, 123.98302788, 157.46064704, 156.76232162,
#        109.69850988, 129.82256634, 250.58159213, 154.42080994,
#        132.17784751,  60.1549415 , 184.76151172, 121.37279958,
# ...

# %% [markdown]
# Assumptions

# %%
plt.scatter(y_test, reg_pred)

# %%
residuals = y_test - reg_pred
residuals
# Out:
# 367   -15.235179
# 219    37.554133
# 72     71.874192
# 55     53.865535
# 371    13.778136
#          ...
# 65    -29.123811
# 114   -35.016877
# 182   -34.097300
# 417   -91.460410
# 224     4.735419
# Name: Outcome, Length: 133, dtype: float64

# %%
#plot the residuals

sns.displot(residuals, kind = 'kde')

# %%
# scatter plot with respect to predictions and residuals

plt.scatter(reg_pred, residuals)

# %%
from sklearn.metrics import  mean_squared_error
from sklearn.metrics import  mean_absolute_error

print(mean_absolute_error(y_test, reg_pred))
print(mean_squared_error(y_test, reg_pred))
print(np.sqrt(mean_squared_error(y_test, reg_pred)))
# Out:
# 44.155016896735816
# 2978.8163271613726
# 54.578533574669926

# %% [markdown]
# R square and adjusted R square

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test, reg_pred)
print(score)
# Out:
# 0.45412938867690333

# %%
# display adjusted R-squared
1 - (1 - score) * (len(y_test) - 1) / (len(y_test) - X_test.shape[1] - 1)
# Out:
# 0.409385895945502

# %% [markdown]
# New Data Prediction

# %%
data.data[0].reshape(1,-1)
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621,  0.02187235, -0.0442235 ,
#         -0.03482076, -0.04340085, -0.00259226,  0.01990842, -0.01764613]])

# %%
scaler.transform(data.data[0].reshape(1,-1))
# Out:
# c:\EndtoEndProject\Diabetes-\venv\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   "X does not have valid feature names, but"
# array([[ 0.79826221,  1.04978132,  1.33907422,  0.43894569, -0.92612247,
#         -0.72338421, -0.94112836, -0.04294148,  0.40638778, -0.40175925]])

# %%
regression.predict(scaler.transform(data.data[0].reshape(1,-1)))
# Out:
# c:\EndtoEndProject\Diabetes-\venv\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   "X does not have valid feature names, but"
# array([208.89331944])

# %% [markdown]
# Pickling the model file for deployment

# %%
import pickle

# %%
pickle.dump(regression, open('regmodel.pkl','wb'))

# %%
pickled_model = pickle.load(open('regmodel.pkl', 'rb'))

# %%
pickled_model.predict(scaler.transform(data.data[0].reshape(1,-1)))
# Out:
# c:\EndtoEndProject\Diabetes-\venv\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   "X does not have valid feature names, but"
# array([208.89331944])
